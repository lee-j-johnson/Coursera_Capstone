# %% [markdown]
# # Applied Data Science Capstone, Week 3--Assignment

# %% [markdown]
# View a version where the maps are visible:
# https://eu-gb.dataplatform.cloud.ibm.com/analytics/notebooks/v2/5aa665ab-947f-4f3b-b571-f7fe37d96899/view?access_token=f42ba5f26a75abc14761876bde94a3bb17adafa1abecde98b3faaec99b69c701

# %% [markdown]
# ## Part 1: Web Scraping

# %% [markdown]
# Import libraries.

# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import requests
print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# Declare url, and scrape data.

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# %%
data  = requests.get(url).text

# %% [markdown]
# Create BeautifulSoup object.

# %%
soup = BeautifulSoup(data,"html5lib")

# %% [markdown]
# Parse HTML to DataFrame.

# %%
table_contents=[]
table=soup.find('table')

for row in table.findAll('td'):
    cell = {}
    if row.span.text=='Not assigned':
        pass
    else:
        cell['PostalCode'] = row.p.text[:3]
        cell['Borough'] = (row.span.text).split('(')[0]
        cell['Neighborhood'] = (((((row.span.text).split('(')[1]).strip(')')).replace(' /',',')).replace(')',' ')).strip(' ')
        table_contents.append(cell)

neighborhoods = pd.DataFrame(table_contents)
neighborhoods['Borough'] = neighborhoods['Borough'].replace({'Downtown TorontoStn A PO Boxes25 The Esplanade':'Downtown Toronto Stn A',
                                                             'East TorontoBusiness reply mail Processing Centre969 Eastern':'East Toronto Business',
                                                             'EtobicokeNorthwest':'Etobicoke Northwest','East YorkEast Toronto':'East York/East Toronto',
                                                             'MississaugaCanada Post Gateway Processing Centre':'Mississauga'})

# %% [markdown]
# neighborhoods DataFrame now available.

# %%
neighborhoods.head()
# Out:
#   PostalCode           Borough                      Neighborhood
# 0        M3A        North York                         Parkwoods
# 1        M4A        North York                  Victoria Village
# 2        M5A  Downtown Toronto         Regent Park, Harbourfront
# 3        M6A        North York  Lawrence Manor, Lawrence Heights
# 4        M7A      Queen's Park     Ontario Provincial Government

# %%
print(f'Toronto neighborhoods DataFrame has {neighborhoods.shape[0]} rows.')
# Out:
# Toronto neighborhoods DataFrame has 103 rows.

# %% [markdown]
# ## Part 2: Geocoding

# %% [markdown]
# Install pgeocode library.

# %%
# !pip install pgeocode
# Out:
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Requirement already satisfied: pgeocode in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (0.3.0)
# Requirement already satisfied: numpy in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from pgeocode) (1.19.2)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from pgeocode) (2.22.0)
# Requirement already satisfied: pandas in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from pgeocode) (1.0.5)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from requests->pgeocode) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from requests->pgeocode) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from requests->pgeocode) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from requests->pgeocode) (2021.5.30)
# Requirement already satisfied: pytz>=2017.2 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from pandas->pgeocode) (2020.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from pandas->pgeocode) (2.8.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas->pgeocode) (1.15.0)

# %% [markdown]
# Import pgeocode library.

# %%
import pgeocode
print('pgeocode imported.')
# Out:
# pgeocode imported.

# %% [markdown]
# Get geospatial data provided by Coursera.

# %%
# !wget -q -O 'Geospatial_Coordinates.csv' https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/labs_v1/Geospatial_Coordinates.csv

# %% [markdown]
# Parse 'Geospatial_Coordinates.csv' to DataFrame.

# %%
coordinates = pd.read_csv('Geospatial_Coordinates.csv')

# %% [markdown]
# coordinates DataFrame now available.

# %%
coordinates.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# Get latitudes and longitudes from postal codes using pgeocode library, else from coordinates DataFrame if pgeocode fails or value is NaN.

# %%
geolocator1 = pgeocode.Nominatim('ca')
postal_codes = neighborhoods['PostalCode'].tolist()
latitudes = []
longitudes = []
for i, postal_code in enumerate(postal_codes):
    result = geolocator1.query_postal_code(postal_code)
    if not result.empty and not result.isnull().values.any():
        latitudes.append(result.latitude)
        longitudes.append(result.longitude)
    else:
        latitudes.append(coordinates.loc[coordinates['Postal Code'] == postal_code].Latitude.item())
        longitudes.append(coordinates.loc[coordinates['Postal Code'] == postal_code].Longitude.item())

# %% [markdown]
# Check data dimensions. Is merge viable?

# %%
print(f'Toronto neighborhoods DataFrame has {neighborhoods.shape[0]} rows.')
print(f'Latitude list has {len(latitudes)} items, and Longitude list has {len(longitudes)} items.')
print(f'Merge is viable? {len(latitudes) == len(longitudes) == neighborhoods.shape[0]}')
# Out:
# Toronto neighborhoods DataFrame has 103 rows.
# Latitude list has 103 items, and Longitude list has 103 items.
# Merge is viable? True

# %% [markdown]
# Make lat_long DataFrame.

# %%
lat_long = pd.DataFrame({'PostalCode':postal_codes, 'Latitude':latitudes, 'Longitude':longitudes})

# %% [markdown]
# lat_long DataFrame now available.

# %%
lat_long.head()
# Out:
#   PostalCode   Latitude  Longitude
# 0        M3A  43.753259 -79.329656
# 1        M4A  43.725882 -79.315572
# 2        M5A  43.654260 -79.360636
# 3        M6A  43.718518 -79.464763
# 4        M7A  43.662301 -79.389494

# %% [markdown]
# Merge neighborhoods and lat_long.

# %%
neighborhoods_geo = pd.merge(neighborhoods,
                             lat_long,
                             how='left',
                             on='PostalCode')

# %% [markdown]
# neighborhoods_geo DataFrame now available.

# %%
neighborhoods_geo.head()
# Out:
#   PostalCode           Borough                      Neighborhood   Latitude  \
# 0        M3A        North York                         Parkwoods  43.753259
# 1        M4A        North York                  Victoria Village  43.725882
# 2        M5A  Downtown Toronto         Regent Park, Harbourfront  43.654260
# 3        M6A        North York  Lawrence Manor, Lawrence Heights  43.718518
# 4        M7A      Queen's Park     Ontario Provincial Government  43.662301
#
#    Longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.464763
# 4 -79.389494

# %% [markdown]
# ## Part 3: Clustering

# %% [markdown]
# Install folium library.

# %%
# !pip install folium
# Out:
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Requirement already satisfied: folium in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (0.12.1)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from folium) (2.11.3)
# Requirement already satisfied: numpy in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from folium) (1.19.2)
# Requirement already satisfied: branca>=0.3.0 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from folium) (0.4.2)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from folium) (2.22.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from requests->folium) (1.25.9)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from requests->folium) (2021.5.30)

# %% [markdown]
# Import libraries.

# %%
from geopy.geocoders import Nominatim
import folium
print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# Get Toronto longitude and latitude.

# %%
city = 'Toronto, Ontario'
geolocator2 = Nominatim(user_agent="ny_explorer")
location = geolocator2.geocode(city)
latitude = location.latitude
longitude = location.longitude
print(f'{latitude}, {longitude}')
# Out:
# 43.6534817, -79.3839347

# %% [markdown]
# Map neighborhoods and boroughs.

# %%
toronto_map = folium.Map(location=[latitude, longitude], zoom_start=11)

for lat, long, borough, neighborhood in zip(neighborhoods_geo['Latitude'],
                                            neighborhoods_geo['Longitude'],
                                            neighborhoods_geo['Borough'],
                                            neighborhoods_geo['Neighborhood']):
    label = f'{neighborhood}; {borough}'
    label = folium.Popup(label)
    folium.Marker(location=[lat, long],
                  popup=label,
                  icon=folium.Icon(color='red')).add_to(toronto_map)

toronto_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_0e9072da6b0745ad8e7b66b193e21438%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_0e9072da6b0745ad8e7b66b193e21438%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_0e9072da6b0745ad8e7b66b193e21438%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_0e9072da6b0745ad8e7b66b193e21438%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
# The code was removed by Watson Studio for sharing.

# %% [markdown]
# Set FourSquare version.

# %%
version = '20210728'

# %% [markdown]
# getNearbyVenues function taken from lab.

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500, limit=100):
    venues_list=[]
    for name, lat, long in zip(names, latitudes, longitudes):
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            client_id, 
            client_secret, 
            version, 
            lat, 
            long, 
            radius, 
            limit)
            
        results = requests.get(url).json()['response']['groups'][0]['items']
        
        venues_list.append([(
            name, 
            lat, 
            long, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=neighborhoods_geo['Neighborhood'],
                                 latitudes=neighborhoods_geo['Latitude'],
                                 longitudes=neighborhoods_geo['Longitude'])

# %% [markdown]
# toronto_venues DataFrame now available.

# %%
toronto_venues.head()
# Out:
#        Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0         Parkwoods              43.753259              -79.329656
# 1         Parkwoods              43.753259              -79.329656
# 2         Parkwoods              43.753259              -79.329656
# 3         Parkwoods              43.753259              -79.329656
# 4  Victoria Village              43.725882              -79.315572
#
#                         Venue  Venue Latitude  Venue Longitude  \
# 0             Brookbanks Park       43.751976       -79.332140
# 1                         KFC       43.754387       -79.333021
# 2               Variety Store       43.751974       -79.333114
# 3  TTC stop - 44 Valley Woods       43.755402       -79.333741
# 4      Victoria Village Arena       43.723481       -79.315635
#
#          Venue Category
# 0                  Park
# 1  Fast Food Restaurant
# 2     Food & Drink Shop
# 3              Bus Stop
# 4          Hockey Arena

# %% [markdown]
# One-hot encode the venue categories, and add neighborhoods to the DataFrame.

# %%
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood']

# %% [markdown]
# Method for obtaining top 10 most common venues taken from lab.

# %%
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()

# %%
def returnMostCommonVenues(row, num_top_venues=10):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10
indicators = ['st', 'nd', 'rd']

columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = returnMostCommonVenues(toronto_grouped.iloc[ind, :], num_top_venues)

# %% [markdown]
# neighborhoods_venues_sorted DataFrame now available.

# %%
neighborhoods_venues_sorted.head()
# Out:
#                                       Neighborhood 1st Most Common Venue  \
# 0                                        Agincourt                Lounge
# 1                           Alderwood, Long Branch           Pizza Place
# 2  Bathurst Manor, Wilson Heights, Downsview North           Coffee Shop
# 3                                  Bayview Village                  Café
# 4                Bedford Park, Lawrence Manor East           Coffee Shop
#
#        2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0  Latin American Restaurant        Breakfast Spot          Skating Rink
# 1                Coffee Shop        Sandwich Place          Dance Studio
# 2                       Bank     Mobile Phone Shop    Frozen Yogurt Shop
# 3        Japanese Restaurant                  Bank    Chinese Restaurant
# 4             Sandwich Place    Italian Restaurant              Pharmacy
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0        Clothing Store             Drugstore        Discount Store
# 1              Pharmacy            Playground                   Pub
# 2           Bridal Shop        Sandwich Place                 Diner
# 3    Dim Sum Restaurant        Discount Store   Distribution Center
# 4               Butcher            Restaurant                  Café
#
#   8th Most Common Venue 9th Most Common Venue   10th Most Common Venue
# 0   Distribution Center               Dog Run         Doner Restaurant
# 1                   Gym      Airport Terminal       Falafel Restaurant
# 2         Deli / Bodega            Restaurant             Intersection
# 3               Dog Run      Doner Restaurant               Donut Shop
# 4                   Pub           Pizza Place  Comfort Food Restaurant

# %% [markdown]
# Import KMeans library.

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# I've chosen 10 clusters for more granularity.

# %%
kclusters = 10

# %% [markdown]
# Generate clusters.

# %%
toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# %%
kmeans = KMeans(n_clusters=kclusters, random_state=1).fit(toronto_grouped_clustering)

# %%
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

# %% [markdown]
# Merge neighborhoods_geoand and neighborhoods_venues_sorted DataFrames.

# %%
toronto_merged = neighborhoods_geo
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

# %% [markdown]
# I've discovered FourSquare has returned NaN values for some postal codes, so I drop rows with NaN values.

# %%
toronto_merged = toronto_merged.dropna(axis=0)

# %% [markdown]
# Clean toronto_merged DataFrame now available.

# %%
toronto_merged.head()
# Out:
#   PostalCode           Borough                      Neighborhood   Latitude  \
# 0        M3A        North York                         Parkwoods  43.753259
# 1        M4A        North York                  Victoria Village  43.725882
# 2        M5A  Downtown Toronto         Regent Park, Harbourfront  43.654260
# 3        M6A        North York  Lawrence Manor, Lawrence Heights  43.718518
# 4        M7A      Queen's Park     Ontario Provincial Government  43.662301
#
#    Longitude  Cluster Labels  1st Most Common Venue 2nd Most Common Venue  \
# 0 -79.329656             0.0      Food & Drink Shop                  Park
# 1 -79.315572             0.0  Portuguese Restaurant           Pizza Place
# 2 -79.360636             2.0            Coffee Shop                   Pub
# 3 -79.464763             2.0         Clothing Store     Accessories Store
# 4 -79.389494             2.0            Coffee Shop                  Café
#
#   3rd Most Common Venue   4th Most Common Venue 5th Most Common Venue  \
# 0              Bus Stop    Fast Food Restaurant  Ethiopian Restaurant
# 1     French Restaurant             Coffee Shop          Hockey Arena
# 2                  Park                  Bakery        Breakfast Spot
# 3   Arts & Crafts Store  Furniture / Home Store           Event Space
# 4      Sushi Restaurant             Yoga Studio         Burrito Place
#
#   6th Most Common Venue 7th Most Common Venue        8th Most Common Venue  \
# 0           Escape Room     Electronics Store  Eastern European Restaurant
# 1      Doner Restaurant    Dim Sum Restaurant                        Diner
# 2                  Café               Theater               Chocolate Shop
# 3           Coffee Shop              Boutique                Women's Store
# 4                   Bar    Italian Restaurant          Japanese Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 0    Dumpling Restaurant     Dim Sum Restaurant
# 1         Discount Store    Distribution Center
# 2             Beer Store                    Spa
# 3  Vietnamese Restaurant        Airport Service
# 4               Beer Bar                    Spa

# %% [markdown]
# Import libraries.

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors
print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# Map the clusters.

# %%
toronto_clusters = folium.Map(location=[latitude, longitude],
                              zoom_start=11,
                              tiles='cartodbpositron')

x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

markers_colors = []
for lat, long, neighborhood, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(neighborhood) + '\nCluster ' + str(int(cluster)))
    folium.CircleMarker(location=[lat, long],
                        radius=5,
                        popup=label,
                        color=rainbow[int(cluster-1)],
                        fill=False,
                        fill_color=rainbow[int(cluster-1)],
                        fill_opacity=0.7).add_to(toronto_clusters)
       
toronto_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_1b38b6b4e9ba429f8e1ca94a14a67860%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_1b38b6b4e9ba429f8e1ca94a14a67860%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_1b38b6b4e9ba429f8e1ca94a14a67860%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_1b38b6b4e9ba429f8e1ca94a14a67860%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# Let's look at each cluster.

# %% [markdown]
# ### Cluster 1

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#         Borough  Cluster Labels  1st Most Common Venue 2nd Most Common Venue  \
# 0    North York             0.0      Food & Drink Shop                  Park
# 1    North York             0.0  Portuguese Restaurant           Pizza Place
# 8     East York             0.0            Pizza Place              Pharmacy
# 10   North York             0.0            Pizza Place                  Park
# 50   North York             0.0            Pizza Place                   Gym
# 70    Etobicoke             0.0            Pizza Place          Intersection
# 72   North York             0.0               Pharmacy           Coffee Shop
# 82  Scarborough             0.0            Pizza Place  Fast Food Restaurant
# 89    Etobicoke             0.0          Grocery Store              Pharmacy
# 90  Scarborough             0.0   Fast Food Restaurant                   Gym
# 93    Etobicoke             0.0            Pizza Place           Coffee Shop
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0               Bus Stop  Fast Food Restaurant  Ethiopian Restaurant
# 1      French Restaurant           Coffee Shop          Hockey Arena
# 8              Gastropub                  Bank    Athletics & Sports
# 10                Bakery   Japanese Restaurant           Yoga Studio
# 50            Donut Shop    Dim Sum Restaurant                 Diner
# 70    Chinese Restaurant        Sandwich Place           Coffee Shop
# 72        Discount Store           Supermarket               Butcher
# 82          Intersection    Italian Restaurant              Pharmacy
# 89           Coffee Shop        Sandwich Place            Beer Store
# 90        Breakfast Spot                  Bank              Pharmacy
# 93        Sandwich Place          Dance Studio              Pharmacy
#
#    6th Most Common Venue      7th Most Common Venue  \
# 0            Escape Room          Electronics Store
# 1       Doner Restaurant         Dim Sum Restaurant
# 8            Flea Market               Intersection
# 10            Donut Shop             Discount Store
# 50        Discount Store        Distribution Center
# 70            Playground  Middle Eastern Restaurant
# 72           Pizza Place              Grocery Store
# 82   Fried Chicken Joint               Noodle House
# 89  Fast Food Restaurant        Fried Chicken Joint
# 90           Pizza Place                Coffee Shop
# 93            Playground                        Pub
#
#           8th Most Common Venue        9th Most Common Venue  \
# 0   Eastern European Restaurant          Dumpling Restaurant
# 1                         Diner               Discount Store
# 8                Breakfast Spot         Gym / Fitness Center
# 10          Distribution Center                      Dog Run
# 50                      Dog Run             Doner Restaurant
# 70               Discount Store           Dim Sum Restaurant
# 72            Electronics Store  Eastern European Restaurant
# 82                         Bank                  Gas Station
# 89                  Pizza Place  Eastern European Restaurant
# 90                 Noodle House                 Intersection
# 93                          Gym             Airport Terminal
#
#    10th Most Common Venue
# 0      Dim Sum Restaurant
# 1     Distribution Center
# 8               Pet Store
# 10       Doner Restaurant
# 50              Drugstore
# 70                  Diner
# 72    Dumpling Restaurant
# 82     Chinese Restaurant
# 89    Dumpling Restaurant
# 90         Sandwich Place
# 93     Falafel Restaurant

# %% [markdown]
# ### Cluster 2

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#        Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 52  North York             1.0                  Park           Yoga Studio
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 52             Drugstore                 Diner        Discount Store
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 52   Distribution Center               Dog Run      Doner Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 52            Donut Shop    Dumpling Restaurant

# %% [markdown]
# ### Cluster 3

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#                    Borough  Cluster Labels 1st Most Common Venue  \
# 2         Downtown Toronto             2.0           Coffee Shop
# 3               North York             2.0        Clothing Store
# 4             Queen's Park             2.0           Coffee Shop
# 7               North York             2.0          Dessert Shop
# 9         Downtown Toronto             2.0           Coffee Shop
# ..                     ...             ...                   ...
# 97        Downtown Toronto             2.0           Coffee Shop
# 98               Etobicoke             2.0                 River
# 99        Downtown Toronto             2.0           Coffee Shop
# 100  East Toronto Business             2.0    Light Rail Station
# 102              Etobicoke             2.0        Hardware Store
#
#     2nd Most Common Venue 3rd Most Common Venue   4th Most Common Venue  \
# 2                     Pub                  Park                  Bakery
# 3       Accessories Store   Arts & Crafts Store  Furniture / Home Store
# 4                    Café      Sushi Restaurant             Yoga Studio
# 7    Caribbean Restaurant    Athletics & Sports     Japanese Restaurant
# 9          Clothing Store   Japanese Restaurant         Bubble Tea Shop
# ..                    ...                   ...                     ...
# 97                   Café                 Hotel     Japanese Restaurant
# 98             Smoke Shop                  Pool             Yoga Studio
# 99       Sushi Restaurant   Japanese Restaurant                 Gay Bar
# 100           Yoga Studio         Garden Center    Gym / Fitness Center
# 102         Tanning Salon         Grocery Store              Kids Store
#
#     5th Most Common Venue 6th Most Common Venue     7th Most Common Venue  \
# 2          Breakfast Spot                  Café                   Theater
# 3             Event Space           Coffee Shop                  Boutique
# 4           Burrito Place                   Bar        Italian Restaurant
# 7                    Café                   Gym               Escape Room
# 9                   Hotel                  Café            Cosmetics Shop
# ..                    ...                   ...                       ...
# 97             Restaurant                   Gym        Seafood Restaurant
# 98       Doner Restaurant    Dim Sum Restaurant                     Diner
# 99             Restaurant  Fast Food Restaurant  Mediterranean Restaurant
# 100            Comic Shop           Pizza Place                Restaurant
# 102  Fast Food Restaurant        Discount Store         Convenience Store
#
#     8th Most Common Venue        9th Most Common Venue 10th Most Common Venue
# 2          Chocolate Shop                   Beer Store                    Spa
# 3           Women's Store        Vietnamese Restaurant        Airport Service
# 4     Japanese Restaurant                     Beer Bar                    Spa
# 7       Electronics Store  Eastern European Restaurant    Dumpling Restaurant
# 9    Fast Food Restaurant             Department Store     Italian Restaurant
# ..                    ...                          ...                    ...
# 97                 Bakery                   Steakhouse            Salad Place
# 98         Discount Store          Distribution Center                Dog Run
# 99            Men's Store                        Hotel            Yoga Studio
# 100         Burrito Place                   Skate Park                Brewery
# 102         Burrito Place               Sandwich Place           Burger Joint
#
# [72 rows x 12 columns]

# %% [markdown]
# ### Cluster 4

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#    Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 64    York             3.0         Jewelry Store           Yoga Studio
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 64            Donut Shop                 Diner        Discount Store
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 64   Distribution Center               Dog Run      Doner Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 64             Drugstore         Farmers Market

# %% [markdown]
# ### Cluster 5

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#         Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 32  Scarborough             4.0            Playground           Yoga Studio
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 32             Drugstore                 Diner        Discount Store
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 32   Distribution Center               Dog Run      Doner Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 32            Donut Shop    Dumpling Restaurant

# %% [markdown]
# ### Cluster 6

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 5, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#         Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 12  Scarborough             5.0                   Bar           Yoga Studio
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 12            Donut Shop                 Diner        Discount Store
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 12   Distribution Center               Dog Run      Doner Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 12             Drugstore         Farmers Market

# %% [markdown]
# ### Cluster 7

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 6, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#        Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 6  Scarborough             6.0  Fast Food Restaurant          Dessert Shop
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 6           Event Space  Ethiopian Restaurant           Escape Room
#
#   6th Most Common Venue        7th Most Common Venue 8th Most Common Venue  \
# 6     Electronics Store  Eastern European Restaurant   Dumpling Restaurant
#
#   9th Most Common Venue 10th Most Common Venue
# 6             Drugstore             Donut Shop

# %% [markdown]
# ### Cluster 8

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 7, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#       Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 11  Etobicoke             7.0                Bakery           Yoga Studio
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 11            Donut Shop                 Diner        Discount Store
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 11   Distribution Center               Dog Run      Doner Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 11             Drugstore         Farmers Market

# %% [markdown]
# ### Cluster 9

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 8, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#         Borough  Cluster Labels       1st Most Common Venue  \
# 53   North York             8.0                  Food Truck
# 57   North York             8.0      Furniture / Home Store
# 101   Etobicoke             8.0  Construction & Landscaping
#
#     2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 53         Baseball Field           Yoga Studio        Discount Store
# 57         Baseball Field            Donut Shop                 Diner
# 101        Baseball Field           Yoga Studio             Drugstore
#
#     5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 53    Distribution Center               Dog Run      Doner Restaurant
# 57         Discount Store   Distribution Center               Dog Run
# 101        Discount Store   Distribution Center               Dog Run
#
#     8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 53             Donut Shop             Drugstore     Dim Sum Restaurant
# 57       Doner Restaurant           Yoga Studio     Dim Sum Restaurant
# 101      Doner Restaurant            Donut Shop    Dumpling Restaurant

# %% [markdown]
# ### Cluster 10

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 9, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#                    Borough  Cluster Labels 1st Most Common Venue  \
# 21                    York             9.0                  Park
# 35  East York/East Toronto             9.0                  Park
# 40              North York             9.0               Airport
# 66              North York             9.0                  Park
# 83         Central Toronto             9.0           Summer Camp
# 85             Scarborough             9.0          Intersection
# 91        Downtown Toronto             9.0                  Park
#
#          2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 21               Women's Store                  Pool           Yoga Studio
# 35                Intersection     Convenience Store            Donut Shop
# 40                        Park            Playground           Yoga Studio
# 66  Construction & Landscaping     Convenience Store           Yoga Studio
# 83                        Park            Playground           Yoga Studio
# 85                        Park            Playground            Donut Shop
# 91                  Playground                 Trail           Yoga Studio
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 21            Donut Shop    Dim Sum Restaurant                 Diner
# 35    Dim Sum Restaurant                 Diner        Discount Store
# 40            Donut Shop    Dim Sum Restaurant                 Diner
# 66             Drugstore        Discount Store   Distribution Center
# 83                 Diner        Discount Store   Distribution Center
# 85    Dim Sum Restaurant                 Diner        Discount Store
# 91            Donut Shop    Dim Sum Restaurant                 Diner
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 21        Discount Store   Distribution Center                Dog Run
# 35   Distribution Center               Dog Run       Doner Restaurant
# 40        Discount Store   Distribution Center                Dog Run
# 66               Dog Run      Doner Restaurant             Donut Shop
# 83               Dog Run      Doner Restaurant             Donut Shop
# 85   Distribution Center               Dog Run       Doner Restaurant
# 91        Discount Store   Distribution Center                Dog Run

# %% [markdown]
# It's interesting to read how Google describes the prevalent boroughs and compare the descriptions to the clusters.

# %% [markdown]
# *North York is an eclectic, multicultural district home to the hands-on Ontario Science Centre and the Aga Khan Museum, with exhibits on Islamic culture in a striking modern building. In the area’s north, Black Creek Pioneer Village is an 1800s living museum. Sprawling Downsview Park includes a lake, event spaces, and a flea and farmers’ market, while Edwards Gardens has a greenhouse, fountains, and botanic gardens.--Google*

# %% [markdown]
# *Downtown Toronto is a buzzing area filled with skyscrapers, restaurants, nightlife, and an eclectic mix of neighbourhoods. It’s also home to iconic attractions like the CN Tower, St. Lawrence Market, and the Royal Ontario Museum, with exhibits on natural history. Bloor Street is an upscale shopping area, and the Eaton Centre is a huge, multistory mall. On the lake, the Harbourfront area has parks and cultural venues.--Google*

# %% [markdown]
# *York is a large district made up of smaller, eclectic neighbourhoods. Eglinton Avenue West is known as “Little Jamaica” for its Caribbean restaurants and shops, and the St. Clair West area has a mix of hip and old-school eateries. Along the Humber River, trails and green spaces include Etienne Brulé Park, popular for watching the salmon run in fall, and James Gardens, with floral blooms and a duck pond.--Google*

# %% [markdown]
# *Scarborough is a large, multicultural area that contains the Scarborough Bluffs, huge cliffs overlooking Lake Ontario, lined with parks, beaches, and hiking trails. Inland, the sprawling Toronto Zoo features global animal pavilions, close-up encounters, and a wildlife health centre. The area is also known for its diverse spread of restaurants, including regional Southeast Asian, Chinese, and Indian cuisine--Google*

# %% [markdown]
# *Suburban Etobicoke is home to several lakefront parks, golf courses, and vast Centennial Park, with a conservatory featuring tropical plants. The 1830s Montgomery’s Inn has a museum, tea room, and pub and hosts a weekly farmers’ market. Islington - City Centre West area is a busy commercial hub, containing shopping complexes and casual chain eateries, plus history-themed murals along Dundas Street West.--Google*

# %% [markdown]
# Scikit-Learn's K-Means clustering seems to isolate some of Toronto's demographic.

# %% [markdown]
# Thanks for reading!
